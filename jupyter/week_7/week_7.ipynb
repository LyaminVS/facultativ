# %%
import numpy as np
import matplotlib.pyplot as plt
import subprocess

# %%
# x_0 = input("x_0")
# v_0 = input("v_0")
# omega = input("omega")
# fr = input("from")
# to = input("to")
# step = input("step")

t = 1
x_0 = str(10)
v_0 = str(0)
omega = str(10)
gamma = str(0.0001)
omega_f = str((float(omega)**2 + 2 * float(gamma)**2)**0.5)
A = str(10)
fr = str(0)
to = str(100)
step = str(0.001)

subprocess.call(["../../facultative_cpp/cpp_7_week/week_7/week_7/main", str(2), x_0, v_0, omega, gamma, omega_f, A, fr, to, step])
# Out:
# 0

# %%
data = np.loadtxt("output_rk.txt").transpose()

# %%
x = data[0]
v = data[1]

# %%
# %matplotlib notebook
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(8,8)
ax.plot(x, v)
ax.set_xlabel('x')
ax.set_ylabel('v')
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0, 0.5, 'v')

# %%
subprocess.call(["../../facultative_cpp/cpp_7_week/week_7/week_7/main", str(1), x_0, v_0, omega, gamma, fr, to, step])
# Out:
# 0

# %%
data_f = np.loadtxt("output_f.txt").transpose()

# %%
x_f = data_f[0]
v_f = data_f[1]

# %%
# %matplotlib notebook
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(8,8)
ax.plot(x_f, v_f)
# Out:
# <img src="data:image/png;base64,..." width="800">
