# %%
import numpy as np
import matplotlib.pyplot as plt
import subprocess
import json
vsvdsvds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/y3/19gt23yd4zg9k93kytyfqj2w0000gn/T/ipykernel_2496/1111424653.py in <module>
#       3 import subprocess
#       4 import json
# ----> 5 vsvdsvds
#
# NameError: name 'vsvdsvds' is not defined

# %%
# x_0 = input("x_0")
# v_0 = input("v_0")
# omega = input("omega")
# fr = input("from")
# to = input("to")
# step = input("step")

t = 1
x_0 = str(1)
v_0 = str(0)
omega = str(10)
gamma = str(0)
omega_f = str(10)
A = str(10)
fr = str(0)
to = str(100)
step = str(0.0001)

consts_file = open("consts_file.json", "w")

consts = {
    "type": str(2),
    "x_0": x_0,
    "v_0": v_0,
    "omega": omega,
    "gamma": gamma,
    "omega_f": omega_f,
    "A": A,
    "fr": fr,
    "to": to,
    "step": step,
}

json.dump(consts, consts_file)
  
consts_file.close()



subprocess.call(["../../facultative_cpp/cpp_7_week/week_7/week_7/main", "consts_file.json"])

# %%
p = subprocess.call(["../../facultative_cpp/cpp_7_week/week_7/week_7/main", str(2), x_0, v_0, omega, gamma, omega_f, A, fr, to, step])

# %%
data = np.loadtxt("output_rk.txt").transpose()

# %%
t = data[0]
x = data[1]
v = data[2]

# %%
# %matplotlib notebook
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(8,8)
ax.plot(x, v)
ax.set_xlabel('x')
ax.set_ylabel('v')
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0, 0.5, 'v')

# %%
# %matplotlib notebook
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(8,8)
ax.plot(t, x)
ax.set_xlabel('t')
ax.set_ylabel('x')
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0, 0.5, 'x')

# %%
subprocess.call(["../../facultative_cpp/cpp_7_week/week_7/week_7/main", str(1), x_0, v_0, omega, gamma, fr, to, step])
# Out:
# 0

# %%
data_f = np.loadtxt("output_f.txt").transpose()

# %%
x_f = data_f[0]
v_f = data_f[1]

# %%
# %matplotlib notebook
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(8,8)
ax.plot(x_f, v_f)
# Out:
# <img src="data:image/png;base64,..." width="800">
