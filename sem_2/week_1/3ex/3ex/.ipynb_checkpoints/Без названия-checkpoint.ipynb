# %%
import numpy as np
import matplotlib.pyplot as plt
import subprocess
subprocess.call(["main"])
arr = np.loadtxt("output.txt").transpose()
plt.bar(arr[0], arr[1])
# Out:
# <BarContainer object of 100 artists>
