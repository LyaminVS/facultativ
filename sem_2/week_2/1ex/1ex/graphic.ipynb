# %%
import numpy as np
import matplotlib.pyplot as plt
import subprocess
import scipy

# %%
subprocess.call(["./main", str(15), str(3)])
# Out:
# 0

# %%
# %matplotlib inline
data = np.loadtxt("./file.txt")
data_real = np.loadtxt("./real_file.txt")
plt.figure(figsize=(8, 8))
plt.plot(data, label="эксперимент")
plt.plot(data_real, label="настоящее распределение")
plt.legend()
