# %%
import subprocess
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
collision_number = 10;
delta_t = 0.1
particle_number = 26

d = {
    "collision_number": str(collision_number),
    "delta_t": str(delta_t),
    "particle_number": str(particle_number)
}
with open('input.json', 'w') as outfile:
    json.dump(d, outfile)

# %%
# !g++ --std=c++20  main.cpp -o main
subprocess.call(["./main", "input.json"])
data = np.loadtxt("test.txt")
# Out:
# input.json

# %%
# %matplotlib notebook
from matplotlib import animation

fig = plt.figure()
fig.subplots_adjust(left=0, right=1, bottom=0, top=1)
ax = fig.add_subplot(111, aspect='equal', autoscale_on=False,
                     xlim=(0, 80), ylim=(-2.4, 2.4))
ball_num = 26
patches = []
for i in range(ball_num):
    patches.append(plt.Circle((0, 0), 1, fc='y'))
# patch = plt.Circle((0, 0), 1, fc='y')
# patch_1 = plt.Circle((0, 0), 1, fc='y')

def init():
    """initialize animation"""
    for i in range(ball_num):
        patches[i].center = (0, 0)
        ax.add_patch(patches[i])
#     patch.center = (0, 0)
#     patch_1.center = (0, 0)
#     ax.add_patch(patch)
#     ax.add_patch(patch_1)
    return tuple(patches)

def animate(i):
    """perform animation step"""
    for j in range(ball_num):
        patches[j].center = (data[i][j], 0)
#     patches[0].center = (data[i][0], 0)
#     patchea[1].center = (data[i][1], 0)
    return tuple(patches)

ani = animation.FuncAnimation(fig, animate, frames=2000,
                              interval=50, blit=True, init_func=init, repeat=True)

writervideo = animation.FFMpegWriter(fps=60)
ani.save('Gas.mp4', writer=writervideo)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/y3/19gt23yd4zg9k93kytyfqj2w0000gn/T/ipykernel_14322/2862936983.py in <module>
#      36
#      37 writervideo = animation.FFMpegWriter(fps=60)
# ---> 38 ani.save('Gas.mp4', writer=writervideo)
#      39
#      40 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1150                     for anim, d in zip(all_anim, data):
#    1151                         # TODO: See if turning off blit is really necessary
# -> 1152                         anim._draw_next_frame(d, blit=False)
#    1153                         if progress_callback is not None:
#    1154                             progress_callback(frame_number, total_frames)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1190         # post- draw, as well as the drawing of the frame itself.
#    1191         self._pre_draw(framedata, blit)
# -> 1192         self._draw_frame(framedata)
#    1193         self._post_draw(framedata, blit)
#    1194
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1753         # Call the func with framedata and args. If blitting is desired,
#    1754         # func needs to return a sequence of any artists that were modified.
# -> 1755         self._drawn_artists = self._func(framedata, *self._args)
#    1756         if self._blit:
#    1757             if self._drawn_artists is None:
#
# /var/folders/y3/19gt23yd4zg9k93kytyfqj2w0000gn/T/ipykernel_14322/2862936983.py in animate(i)
#      27     """perform animation step"""
#      28     for j in range(ball_num):
# ---> 29         patches[j].center = (data[i][j], 0)
#      30 #     patches[0].center = (data[i][0], 0)
#      31 #     patchea[1].center = (data[i][1], 0)
#
# IndexError: index 1596 is out of bounds for axis 0 with size 1596
